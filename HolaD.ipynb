# %% [markdown]
# <a href="https://colab.research.google.com/github/a01735108-source/Repositorio_de_prueba/blob/main/HolaD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
#numpy es la libreria para los calculos dentro del codigo
