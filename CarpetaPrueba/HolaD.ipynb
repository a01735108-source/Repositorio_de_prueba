# %% [markdown]
# <a href="https://colab.research.google.com/github/a01735108-source/Repositorio_de_prueba/blob/main/CarpetaPrueba/HolaD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy es la libreria para los calculos dentro del codigo
import numpy as np
import pandas as pd

# %% [markdown]
# "Este es un cambio en mi computadora"
# LOL
